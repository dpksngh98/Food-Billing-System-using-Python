# %%
from tkinter import *
import time
import datetime
import random
import tkinter.messagebox

root =Tk()
root.geometry("1350x700+0+0")
root.title("Food Billing System")
root.configure(background='turquoise3')

Tops = Frame(root,bg='ivory3',bd=20,pady=5,relief=RIDGE)
Tops.pack(side=TOP)

lblTitle=Label(Tops,font=('arial',60,'bold'),text='Food Billing System',bd=21,bg='red',
                fg='black',justify=CENTER)
lblTitle.grid(row=0)


ReceiptCal_F = Frame(root,bg='ivory3',bd=10,relief=RIDGE)
ReceiptCal_F.pack(side=RIGHT)

Buttons_F=Frame(ReceiptCal_F,bg='ivory3',bd=3,relief=RIDGE)
Buttons_F.pack(side=BOTTOM)

Cal_F=Frame(ReceiptCal_F,bg='turquoise3',bd=6,relief=RIDGE)
Cal_F.pack(side=TOP)

Receipt_F=Frame(ReceiptCal_F,bg='turquoise3',bd=4,relief=RIDGE)
Receipt_F.pack(side=BOTTOM)

MenuFrame = Frame(root,bg='ivory3',bd=10,relief=RIDGE)
MenuFrame.pack(side=LEFT)
Cost_F=Frame(MenuFrame,bg='turquoise3',bd=4)
Cost_F.pack(side=BOTTOM)
Drinks_F=Frame(MenuFrame,bg='turquoise3',bd=4)
Drinks_F.pack(side=TOP)


Drinks_F=Frame(MenuFrame,bg='turquoise3',bd=4,relief=RIDGE)
Drinks_F.pack(side=LEFT)
Food_F=Frame(MenuFrame,bg='turquoise3',bd=4,relief=RIDGE)
Food_F.pack(side=RIGHT)
###################################################variables################################################

var1=IntVar()
var2=IntVar()
var3=IntVar()
var4=IntVar()
var5=IntVar()
var6=IntVar()
var7=IntVar()
var8=IntVar()
var9=IntVar()
var10=IntVar()
var11=IntVar()
var12=IntVar()
var13=IntVar()
var14=IntVar()
var15=IntVar()
var16=IntVar()

DateofOrder = StringVar()
Receipt_Ref = StringVar()
PaidTax = StringVar()
SubTotal = StringVar()
TotalCost = StringVar()
CostofFood = StringVar()
CostofDrinks = StringVar()
ServiceCharge = StringVar()

text_Input = StringVar()
operator = ""

E_Shake = StringVar()
E_Ice_Cream = StringVar()
E_Masala_Chae = StringVar()
E_Lemonade = StringVar()
E_Cappuccino = StringVar()
E_Hot_Chocolate = StringVar()
E_Soda = StringVar()
E_ColdCoffee = StringVar()

E_Pancakes = StringVar()
E_VegBurger = StringVar()
E_White_Sauce_Pasta = StringVar()
E_Chips = StringVar()
E_Sandwich = StringVar()
E_Fries = StringVar()
E_Momos = StringVar()
E_Pizza = StringVar()

E_Shake.set("0")
E_Ice_Cream.set("0")
E_Masala_Chae.set("0")
E_Lemonade.set("0")
E_Cappuccino.set("0")
E_Hot_Chocolate.set("0")
E_Soda.set("0")
E_ColdCoffee.set("0")

E_Pancakes.set("0")
E_VegBurger.set("0")
E_White_Sauce_Pasta.set("0")
E_Chips.set("0")
E_Sandwich.set("0")
E_Fries.set("0")
E_Momos.set("0")
E_Pizza.set("0")

DateofOrder.set(time.strftime("%d/%m/%y"))

##########################################Function Declaration####################################################

def iExit():
    iExit=tkinter.messagebox.askyesno("Exit Restaurant System","Confirm if you want to exit")
    if iExit > 0:
        root.destroy()
        return

def Reset():

    PaidTax.set("")
    SubTotal.set("")
    TotalCost.set("")
    CostofFood.set("")
    CostofDrinks.set("")
    ServiceCharge.set("")
    txtReceipt.delete("1.0",END)


    E_Shake.set("0")
    E_Ice_Cream.set("0")
    E_Masala_Chae.set("0")
    E_Lemonade.set("0")
    E_Cappuccino.set("0")
    E_Hot_Chocolate.set("0")
    E_Soda.set("0")
    E_ColdCoffee.set("0")

    E_Pancakes.set("0")
    E_VegBurger.set("0")
    E_White_Sauce_Pasta.set("0")
    E_Chips.set("0")
    E_Sandwich.set("0")
    E_Fries.set("0")
    E_Momos.set("0")
    E_Pizza.set("0")

    var1.set(0)
    var2.set(0)
    var3.set(0)
    var4.set(0)
    var5.set(0)
    var6.set(0)
    var7.set(0)
    var8.set(0)
    var9.set(0)
    var10.set(0)
    var11.set(0)
    var12.set(0)
    var13.set(0)
    var14.set(0)
    var15.set(0)
    var16.set(0)


    txtShake.configure(state=DISABLED)
    txtIce_Cream.configure(state=DISABLED)
    txtMasala_Chae.configure(state=DISABLED)
    txtLemonade.configure(state=DISABLED)
    txtCappuccino.configure(state=DISABLED)
    txtHot_Chocolate.configure(state=DISABLED)
    txtSoda.configure(state=DISABLED)
    txtColdCoffee.configure(state=DISABLED)
    txtPancakes.configure(state=DISABLED)
    txtVegBurger.configure(state=DISABLED)
    txtWhite_Sauce_Pasta.configure(state=DISABLED)
    txtChips.configure(state=DISABLED)
    txtSandwich.configure(state=DISABLED)
    txtFries.configure(state=DISABLED)
    txtMomos.configure(state=DISABLED)
    txtPizza.configure(state=DISABLED)

def CostofItem():
    Item1=float(E_Shake.get())
    Item2=float(E_Ice_Cream.get())
    Item3=float(E_Masala_Chae.get())
    Item4=float(E_Lemonade.get())
    Item5=float(E_Cappuccino.get())
    Item6=float(E_Hot_Chocolate.get())
    Item7=float(E_Soda.get())
    Item8=float(E_ColdCoffee.get())

    Item9=float(E_Pancakes.get())
    Item10=float(E_VegBurger.get())
    Item11=float(E_White_Sauce_Pasta.get())
    Item12=float(E_Chips.get())
    Item13=float(E_Sandwich.get())
    Item14=float(E_Fries.get())
    Item15=float(E_Momos.get())
    Item16=float(E_Pizza.get())

    PriceofDrinks =(Item1 * 65) + (Item2 * 75) + (Item3 * 99) + (Item4 * 130) + (Item5 * 180) + (Item6 * 75) + (Item7 * 75) + (Item8 * 89)

    PriceofFood =(Item9 * 260) + (Item10 * 175) + (Item11 * 255) + (Item12 * 480) + (Item13 * 240) + (Item14 * 110) + (Item15 * 340) + (Item16 * 213)



    DrinksPrice = "Rs",str('%.2f'%(PriceofDrinks))
    FoodPrice =  "Rs",str('%.2f'%(PriceofFood))
    CostofFood.set(FoodPrice)
    CostofDrinks.set(DrinksPrice)
    SC = "Rs",str('%.2f'%(1.59))
    ServiceCharge.set(SC)

    SubTotalofITEMS = "Rs",str('%.2f'%(PriceofDrinks + PriceofFood + 1.59))
    SubTotal.set(SubTotalofITEMS)

    Tax = "Rs",str('%.2f'%((PriceofDrinks + PriceofFood + 1.59) * 0.15))
    PaidTax.set(Tax)

    TT=((PriceofDrinks + PriceofFood + 1.59) * 0.15)
    TC="Rs",str('%.2f'%(PriceofDrinks + PriceofFood + 1.59 + TT))
    TotalCost.set(TC)


def chkShake():
    if(var1.get() == 1):
        txtShake.configure(state = NORMAL)
        txtShake.focus()
        txtShake.delete('0',END)
        E_Shake.set("")
    elif(var1.get() == 0):
        txtShake.configure(state = DISABLED)
        E_Shake.set("0")

def chkIce_Cream():
    if(var2.get() == 1):
        txtIce_Cream.configure(state = NORMAL)
        txtIce_Cream.focus()
        txtIce_Cream.delete('0',END)
        E_Ice_Cream.set("")
    elif(var2.get() == 0):
        txtIce_Cream.configure(state = DISABLED)
        E_Ice_Cream.set("0")

def chk_Masala_Chae():
    if(var3.get() == 1):
        txtMasala_Chae.configure(state = NORMAL)
        txtMasala_Chae.delete('0',END)
        txtMasala_Chae.focus()
    elif(var3.get() == 0):
        txtMasala_Chae.configure(state = DISABLED)
        E_Masala_Chae.set("0")

def chk_Lemonade():
    if(var4.get() == 1):
        txtLemonade.configure(state = NORMAL)
        txtLemonade.delete('0',END)
        txtLemonade.focus()
    elif(var4.get() == 0):
        txtLemonade.configure(state = DISABLED)
        E_Lemonade.set("0")

def chk_Cappuccino():
    if(var5.get() == 1):
        txtCappuccino.configure(state = NORMAL)
        txtCappuccino.delete('0',END)
        txtCappuccino.focus()
    elif(var5.get() == 0):
        txtCappuccino.configure(state = DISABLED)
        E_Cappuccino.set("0")

def chk_Hot_Chocolate():
    if(var6.get() == 1):
        txtHot_Chocolate.configure(state = NORMAL)
        txtHot_Chocolate.delete('0',END)
        txtHot_Chocolate.focus()
    elif(var6.get() == 0):
        txtHot_Chocolate.configure(state = DISABLED)
        E_Hot_Chocolate.set("0")

def chk_Soda():
    if(var7.get() == 1):
        txtSoda.configure(state = NORMAL)
        txtSoda.delete('0',END)
        txtSoda.focus()
    elif(var7.get() == 0):
        txtSoda.configure(state = DISABLED)
        E_Soda.set("0")

def chk_ColdCoffee():
    if(var8.get() == 1):
        txtColdCoffee.configure(state = NORMAL)
        txtColdCoffee.delete('0',END)
        txtColdCoffee.focus()
    elif(var8.get() == 0):
        txtColdCoffee.configure(state = DISABLED)
        E_ColdCoffee.set("0")

def chk_Pancakes():
    if(var9.get() == 1):
        txtPancakes.configure(state = NORMAL)
        txtPancakes.delete('0',END)
        txtPancakes.focus()
    elif(var9.get() == 0):
        txtPancakes.configure(state = DISABLED)
        E_Pancakes.set("0")

def chk_VegBurger():
    if(var10.get() == 1):
        txtVegBurger.configure(state = NORMAL)
        txtVegBurger.delete('0',END)
        txtVegBurger.focus()
    elif(var10.get() == 0):
        txtVegBurger.configure(state = DISABLED)
        E_VegBurger.set("0")

def chk_White_Sauce_Pasta():
    if(var11.get() == 1):
        txtWhite_Sauce_Pasta.configure(state = NORMAL)
        txtWhite_Sauce_Pasta.delete('0',END)
        txtWhite_Sauce_Pasta.focus()
    elif(var11.get() == 0):
        txtWhite_Sauce_Pasta.configure(state = DISABLED)
        E_White_Sauce_Pasta.set("0")

def chk_Chips():
    if(var12.get() == 1):
        txtChips.configure(state = NORMAL)
        txtChips.delete('0',END)
        txtChips.focus()
    elif(var12.get() == 0):
        txtChips.configure(state = DISABLED)
        E_Chips.set("0")

def chk_Sandwich():
    if(var13.get() == 1):
        txtSandwich.configure(state = NORMAL)
        txtSandwich.delete('0',END)
        txtSandwich.focus()
    elif(var13.get() == 0):
        txtSandwich.configure(state = DISABLED)
        E_Sandwich.set("0")

def chk_Fries():
    if(var14.get() == 1):
        txtFries.configure(state = NORMAL)
        txtFries.delete('0',END)
        txtFries.focus()
    elif(var14.get() == 0):
        txtFries.configure(state = DISABLED)
        E_Fries.set("0")

def chk_Momos():
    if(var15.get() == 1):
        txtMomos.configure(state = NORMAL)
        txtMomos.delete('0',END)
        txtMomos.focus()
    elif(var15.get() == 0):
        txtMomos.configure(state = DISABLED)
        E_Momos.set("0")

def chk_Pizza():
    if(var16.get() == 1):
        txtPizza.configure(state = NORMAL)
        txtPizza.delete('0',END)
        txtPizza.focus()
    elif(var16.get() == 0):
        txtPizza.configure(state = DISABLED)
        E_Pizza.set("0")

def Receipt():
    txtReceipt.delete("1.0",END)
    x=random.randint(10908,500876)
    randomRef= str(x)
    Receipt_Ref.set("Bill"+ randomRef)


    txtReceipt.insert(END,'Receipt Ref:\t\t\t'+Receipt_Ref.get() +'\t'+ DateofOrder.get() +'\n')
    txtReceipt.insert(END,'Items\t\t\t\t'+"Cost of Items \n")
    txtReceipt.insert(END,'Shake:\t\t\t\t\t' + E_Shake.get() +'\n')
    txtReceipt.insert(END,'Ice_Cream:\t\t\t\t\t'+ E_Ice_Cream.get()+'\n')
    txtReceipt.insert(END,'Masala_Chae:\t\t\t\t\t'+ E_Masala_Chae.get()+'\n')
    txtReceipt.insert(END,'Lemonade:\t\t\t\t\t'+ E_Lemonade.get()+'\n')
    txtReceipt.insert(END,'Cappuccino:\t\t\t\t\t'+ E_Cappuccino.get()+'\n')
    txtReceipt.insert(END,'Hot_Chocolate:\t\t\t\t\t'+ E_Hot_Chocolate.get()+'\n')
    txtReceipt.insert(END,'Soda:\t\t\t\t\t'+ E_Soda.get()+'\n')
    txtReceipt.insert(END,'ColdCoffee:\t\t\t\t\t'+ E_ColdCoffee.get()+'\n')
    txtReceipt.insert(END,'Pancakes:\t\t\t\t\t'+ E_Pancakes.get()+'\n')
    txtReceipt.insert(END,'VegBurger:\t\t\t\t\t'+ E_VegBurger.get()+'\n')
    txtReceipt.insert(END,'White_Sauce_Pasta:\t\t\t\t\t'+ E_White_Sauce_Pasta.get()+'\n')
    txtReceipt.insert(END,'Chips:\t\t\t\t\t'+ E_Chips.get()+'\n')
    txtReceipt.insert(END,'Sandwich:\t\t\t\t\t'+ E_Sandwich.get()+'\n')
    txtReceipt.insert(END,'Fries:\t\t\t\t\t'+ E_Fries.get()+'\n')
    txtReceipt.insert(END,'Momos:\t\t\t\t\t'+ E_Momos.get()+'\n')
    txtReceipt.insert(END,'Pizza:\t\t\t\t\t'+ E_Pizza.get()+'\n')
    txtReceipt.insert(END,'Cost of Drinks:\t\t\t\t\t'+ CostofDrinks.get()+'\nTax Paid:\t\t\t\t'+PaidTax.get()+"\n")
    txtReceipt.insert(END,'Cost of Foods:\t\t\t\t'+ CostofFood.get()+'\nSubTotal:\t\t\t\t'+str(SubTotal.get())+"\n")
    txtReceipt.insert(END,'Service Charge:\t\t\t\t'+ ServiceCharge.get()+'\nTotal Cost:\t\t\t\t'+str(TotalCost.get())+"\n")


#########################################Drinks####################################################################
Shake=Checkbutton(Drinks_F,text='Shake',variable=var1,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chkShake).grid(row=0,sticky=W)
Ice_Cream=Checkbutton(Drinks_F,text='Ice_Cream',variable=var2,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chkIce_Cream).grid(row=1,sticky=W)
Masala_Chae=Checkbutton(Drinks_F,text='Masala_Chae',variable=var3,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_Masala_Chae).grid(row=2,sticky=W)
Lemonade=Checkbutton(Drinks_F,text='Lemonade',variable=var4,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_Lemonade).grid(row=3,sticky=W)
Cappuccino=Checkbutton(Drinks_F,text='Cappuccino',variable=var5,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_Cappuccino).grid(row=4,sticky=W)
Hot_Chocolate=Checkbutton(Drinks_F,text='Hot_Chocolate',variable=var6,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_Hot_Chocolate).grid(row=5,sticky=W)
Soda=Checkbutton(Drinks_F,text='Soda',variable=var7,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_Soda).grid(row=6,sticky=W)
ColdCoffee=Checkbutton(Drinks_F,text='ColdCoffee',variable=var8,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='turquoise3',command=chk_ColdCoffee).grid(row=7,sticky=W)
##############################################Drink Entry###############################################################

txtShake = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Shake)
txtShake.grid(row=0,column=1)

txtIce_Cream = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Ice_Cream)
txtIce_Cream.grid(row=1,column=1)

txtMasala_Chae = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Masala_Chae)
txtMasala_Chae.grid(row=2,column=1)

txtLemonade= Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Lemonade)
txtLemonade.grid(row=3,column=1)

txtCappuccino = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Cappuccino)
txtCappuccino.grid(row=4,column=1)

txtHot_Chocolate = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Hot_Chocolate)
txtHot_Chocolate.grid(row=5,column=1)

txtSoda = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_Soda)
txtSoda.grid(row=6,column=1)

txtColdCoffee = Entry(Drinks_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_ColdCoffee)
txtColdCoffee.grid(row=7,column=1)
#############################################Foods######################################################################

Pancakes = Checkbutton(Food_F,text="Pancakes\t\t\t ",variable=var9,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Pancakes).grid(row=0,sticky=W)
VegBurger = Checkbutton(Food_F,text="VegBurger",variable=var10,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_VegBurger).grid(row=1,sticky=W)
White_Sauce_Pasta = Checkbutton(Food_F,text="White_Sauce_Pasta ",variable=var11,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_White_Sauce_Pasta).grid(row=2,sticky=W)
Chips = Checkbutton(Food_F,text="Rice Plate ",variable=var12,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Chips).grid(row=3,sticky=W)
Sandwich = Checkbutton(Food_F,text="Sandwich ",variable=var13,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Sandwich).grid(row=4,sticky=W)
Fries = Checkbutton(Food_F,text="Fries ",variable=var14,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Fries).grid(row=5,sticky=W)
Momos = Checkbutton(Food_F,text="Momos ",variable=var15,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Momos).grid(row=6,sticky=W)
Pizza = Checkbutton(Food_F,text="Pizza ",variable=var16,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='turquoise3',command=chk_Pizza).grid(row=7,sticky=W)
################################################Entry Box For Cake##########################################################
txtPancakes=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Pancakes)
txtPancakes.grid(row=0,column=1)

txtVegBurger=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_VegBurger)
txtVegBurger.grid(row=1,column=1)

txtWhite_Sauce_Pasta=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_White_Sauce_Pasta)
txtWhite_Sauce_Pasta.grid(row=2,column=1)

txtChips=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Chips)
txtChips.grid(row=3,column=1)

txtSandwich=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Sandwich)
txtSandwich.grid(row=4,column=1)

txtFries=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Fries)
txtFries.grid(row=5,column=1)

txtMomos=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Momos)
txtMomos.grid(row=6,column=1)

txtPizza=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_Pizza)
txtPizza.grid(row=7,column=1)
###########################################ToTal Cost################################################################################
lblCostofDrinks=Label(Cost_F,font=('arial',14,'bold'),text='Cost of Drinks\t',bg='turquoise3',
                fg='black',justify=CENTER)
lblCostofDrinks.grid(row=0,column=0,sticky=W)
txtCostofDrinks=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=CostofDrinks)
txtCostofDrinks.grid(row=0,column=1)

lblCostofFood=Label(Cost_F,font=('arial',14,'bold'),text='Cost of Foods  ',bg='turquoise3',
                fg='black',justify=CENTER)
lblCostofFood.grid(row=1,column=0,sticky=W)
txtCostofFood=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=CostofFood)
txtCostofFood.grid(row=1,column=1)

lblServiceCharge=Label(Cost_F,font=('arial',14,'bold'),text='Service Charge',bg='turquoise3',
                fg='black',justify=CENTER)
lblServiceCharge.grid(row=2,column=0,sticky=W)
txtServiceCharge=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=ServiceCharge)
txtServiceCharge.grid(row=2,column=1)
###########################################################Payment information###################################################

lblPaidTax=Label(Cost_F,font=('arial',14,'bold'),text='\tPaid Tax',bg='turquoise3',bd=7,
                fg='black',justify=CENTER)
lblPaidTax.grid(row=0,column=2,sticky=W)
txtPaidTax=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=PaidTax)
txtPaidTax.grid(row=0,column=3)

lblSubTotal=Label(Cost_F,font=('arial',14,'bold'),text='\tSub Total',bg='turquoise3',bd=7,
                fg='black',justify=CENTER)
lblSubTotal.grid(row=1,column=2,sticky=W)
txtSubTotal=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=SubTotal)
txtSubTotal.grid(row=1,column=3)

lblTotalCost=Label(Cost_F,font=('arial',14,'bold'),text='\tTotal',bg='turquoise3',bd=7,
                fg='black',justify=CENTER)
lblTotalCost.grid(row=2,column=2,sticky=W)
txtTotalCost=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=TotalCost)
txtTotalCost.grid(row=2,column=3)

#############################################RECEIPT###############################################################################
txtReceipt=Text(Receipt_F,width=46,height=12,bg='white',bd=4,font=('arial',12,'bold'))
txtReceipt.grid(row=0,column=0)


###########################################BUTTONS################################################################################
btnTotal=Button(Buttons_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Total',
                        bg='turquoise3',command=CostofItem).grid(row=0,column=0)
btnReceipt=Button(Buttons_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Receipt',
                        bg='green3',command=Receipt).grid(row=0,column=1)
btnReset=Button(Buttons_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Reset',
                        bg='turquoise3',command=Reset).grid(row=0,column=2)
btnExit=Button(Buttons_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Exit',
                        bg='red',command=iExit).grid(row=0,column=3)

###################################Calculator Display################################################################################




def btnClick(numbers):
    global operator
    operator = operator + str(numbers)
    text_Input.set(operator)

def btnClear():
    global operator
    operator = ""
    text_Input.set("")

def btnEquals():
    global operator
    sumup = str(eval(operator))
    text_Input.set(sumup)
    operator = ""




#############################################Calculator###############################################################################
txtDisplay=Entry(Cal_F,width=45,bg='white',bd=4,font=('arial',12,'bold'),justify=RIGHT,textvariable=text_Input)
txtDisplay.grid(row=0,column=0,columnspan=4,pady=1)
txtDisplay.insert(0,"0")

###########################################CALCULATOR BUTTONS################################################################################
btn7=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='7',
                        bg='blue2',command=lambda:btnClick(7)).grid(row=2,column=0)
btn8=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='8',
                        bg='blue2',command=lambda:btnClick(8)).grid(row=2,column=1)
btn9=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='9',
                        bg='blue2',command=lambda:btnClick(9)).grid(row=2,column=2)
btnAdd=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='+',
                        bg='blue2',command=lambda:btnClick('+')).grid(row=2,column=3)
###########################################CALCULATOR BUTTONS################################################################################
btn4=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='4',
                        bg='blue2',command=lambda:btnClick(4)).grid(row=3,column=0)
btn5=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='5',
                        bg='blue2',command=lambda:btnClick(5)).grid(row=3,column=1)
btn6=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='6',
                        bg='blue2',command=lambda:btnClick(6)).grid(row=3,column=2)
btnSub=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='-',
                        bg='blue2',command=lambda:btnClick('-')).grid(row=3,column=3)
###########################################CALCULATOR BUTTONS################################################################################
btn1=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='1',
                        bg='blue2',command=lambda:btnClick(1)).grid(row=4,column=0)
btn2=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='2',
                        bg='blue2',command=lambda:btnClick(2)).grid(row=4,column=1)
btn3=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='3',
                        bg='blue2',command=lambda:btnClick(3)).grid(row=4,column=2)
btnMulti=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='*',
                        bg='blue2',command=lambda:btnClick('*')).grid(row=4,column=3)
###########################################CALCULATOR BUTTONS################################################################################
btn0=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='0',
                        bg='blue2',command=lambda:btnClick(0)).grid(row=5,column=0)
btnClear=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='C',
                        bg='blue2',command=btnClear).grid(row=5,column=1)
btnEqual=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='=',
                        bg='blue2',command=btnEquals).grid(row=5,column=2)
btnDiv=Button(Cal_F,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='/',
                        bg='blue2',command=lambda:btnClick('/')).grid(row=5,column=3)







root.mainloop()
